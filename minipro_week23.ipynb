# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Find the most appropriate price fluctuation division
def best_fluc(dataframe):
    best_fluc = 0
    df = dataframe
    min_diff = 10000
    for x in np.arange(0,10,0.5):
        fluc_percentage = x
        rising_count = falling_count = stable_count = 0
        for i in range(0,np.shape(df)[0]):
            if df.loc[i,'price_change'] > x:
                rising_count+=1
            elif df.loc[i,'price_change'] < -x:
                falling_count+=1
            else:
                stable_count+=1
        aver = (rising_count+falling_count+stable_count)/3
        curr_diff = np.average([abs(rising_count-aver),abs(falling_count-aver),abs(stable_count-aver)])
        if curr_diff < min_diff:
            min_diff = curr_diff
            best_fluc = x
    return best_fluc

# %%
# Set the directory paths for input and output files
input_dir = 'CSV/'
output_dir = 'CSV_10/'

# Loop over each input file in the input directory
for filename in os.listdir(input_dir):
    if not filename.endswith('.csv'):
        continue

    with open(os.path.join(input_dir, filename), 'r') as file:
        reader = csv.reader(file)
        header = next(reader)
        data = [tuple(map(float, row)) for row in reader]

    # compute the averages for each block of rows
    n = len(data)
    i = 0
    block = []
    averages = []
    while i < n:
        block.append(data[i])
        j = i + 1
        # Set the time interval to 10s
        while j < n and data[j][0] - data[i][0] <= 10:
            block.append(data[j])
            j += 1
        # compute the average of the accumulated rows
        if block:
            average =(block[0][0],) + tuple(round(sum(x[i] for x in block) / len(block),2) for i in range(1, len(block[0])))
            averages.append(average)
        # reset the accumulation for the next block of rows
        block = []
        i = j    

    # covert list to df
    df = pd.DataFrame(averages, columns=['time', 'bid_weighted_average', 'bid_high','bid_volumn',\
                         'ask_weighted_average','ask_low','ask_volumn',\
                         'mid_price','spread','bid_ask_ratio'])

    # create new column vectors for categories
    df['Trend'] = 0
    df['rising'] = 0
    df['falling'] = 0
    df['stable'] = 0

    # create new column for price changes
    df['price_change'] = 0
    for i in range(1,np.shape(df)[0]):
        df.loc[i,'price_change'] = ((df.loc[i,'mid_price'] - df.loc[i-1,'mid_price']) / df.loc[i-1,'mid_price']) * 100
        
    # Choose the x value that makes the three categories most evenly distributed
    fluc_percentage = best_fluc(df)
    print(fluc_percentage)

    for i in range(0,np.shape(df)[0]):
        if df.loc[i,'price_change'] > fluc_percentage:
            df.loc[i,'Trend'] = 1
            df.loc[i,'rising'] = 1
        elif df.loc[i,'price_change'] < -fluc_percentage:
            df.loc[i,'Trend'] = 2
            df.loc[i,'falling'] = 1
        else:
            df.loc[i,'Trend'] = 0
            df.loc[i,'stable'] = 1

    # drop the first row
    df = df.drop(0)

    # drop the price_change column
    df = df.drop('price_change', axis=1)

    rising_count = df['rising'].sum()
    falling_count = df['falling'].sum()
    stable_count = df['stable'].sum()
    total_count = rising_count+falling_count+stable_count
    rising_percentage = (rising_count / total_count) * 100
    falling_percentage = (falling_count / total_count) * 100
    stable_percentage = (stable_count / total_count) * 100
    print(f"Percentage of rising: {rising_percentage:.2f}%")
    print(f"Percentage of falling: {falling_percentage:.2f}%")
    print(f"Percentage of stable: {stable_percentage:.2f}%")

    # save as a new csv
    df.to_csv(os.path.join(output_dir,filename), index=False)
# Out:
# 1.0
# Percentage of rising: 28.50%
# Percentage of falling: 32.44%
# Percentage of stable: 39.06%
# 1.0
# Percentage of rising: 29.53%
# Percentage of falling: 34.76%
# Percentage of stable: 35.72%
# 0.5
# Percentage of rising: 34.93%
# Percentage of falling: 39.86%
# Percentage of stable: 25.21%
# 0.5
# Percentage of rising: 34.59%
# Percentage of falling: 37.60%
# Percentage of stable: 27.81%
# 2.5
# Percentage of rising: 32.05%
# Percentage of falling: 36.13%
# Percentage of stable: 31.82%
# 2.0
# Percentage of rising: 29.21%
# Percentage of falling: 34.70%
# Percentage of stable: 36.09%
# 2.0
# Percentage of rising: 30.93%
# Percentage of falling: 36.23%
# Percentage of stable: 32.85%
# 1.5
# Percentage of rising: 29.21%
# Percentage of falling: 33.51%
# Percentage of stable: 37.28%
# 4.0
# Percentage of rising: 31.68%
# Percentage of falling: 35.75%
# Percentage of stable: 32.57%
# 4.5
# Percentage of rising: 30.84%
# Percentage of falling: 33.69%
# Percentage of stable: 35.47%
# 2.0
# Percentage of rising: 29.37%
# Percentage of falling: 35.47%
# Percentage of stable: 35.17%
# 1.0
# Percentage of rising: 31.17%
# Percentage of falling: 36.93%
# Percentage of stable: 31.90%
# 1.0
# Percentage of rising: 31.42%
# Percentage of falling: 36.75%
# Percentage of stable: 31.82%
# 2.5
# Percentage of rising: 29.96%
# Percentage of falling: 34.99%
# Percentage of stable: 35.05%
# 1.5
# Percentage of rising: 29.88%
# Percentage of falling: 35.41%
# Percentage of stable: 34.71%
# 3.0
# Percentage of rising: 30.84%
# Percentage of falling: 35.44%
# Percentage of stable: 33.72%
# 3.0
# Percentage of rising: 31.82%
# Percentage of falling: 34.64%
# Percentage of stable: 33.54%
# 1.0
# Percentage of rising: 26.78%
# Percentage of falling: 31.88%
# Percentage of stable: 41.34%
# 2.5
# Percentage of rising: 31.58%
# Percentage of falling: 34.53%
# Percentage of stable: 33.90%
# 2.5
# Percentage of rising: 31.67%
# Percentage of falling: 36.27%
# Percentage of stable: 32.06%
# 3.0
# Percentage of rising: 31.69%
# Percentage of falling: 36.33%
# Percentage of stable: 31.99%
# 2.0
# Percentage of rising: 31.62%
# Percentage of falling: 36.29%
# Percentage of stable: 32.09%
# 1.5
# Percentage of rising: 29.77%
# Percentage of falling: 34.64%
# Percentage of stable: 35.60%
# 3.5
# Percentage of rising: 31.69%
# Percentage of falling: 35.00%
# Percentage of stable: 33.31%
# 4.5
# Percentage of rising: 32.00%
# Percentage of falling: 35.08%
# Percentage of stable: 32.92%
# 5.5
# Percentage of rising: 31.63%
# Percentage of falling: 34.22%
# Percentage of stable: 34.15%
# 5.0
# Percentage of rising: 32.12%
# Percentage of falling: 35.24%
# Percentage of stable: 32.65%
# 5.0
# Percentage of rising: 31.33%
# Percentage of falling: 34.71%
# Percentage of stable: 33.95%
# 5.5
# Percentage of rising: 32.28%
# Percentage of falling: 34.54%
# Percentage of stable: 33.18%
# 2.5
# Percentage of rising: 31.67%
# Percentage of falling: 36.27%
# Percentage of stable: 32.06%
# 4.5
# Percentage of rising: 31.66%
# Percentage of falling: 35.01%
# Percentage of stable: 33.32%
# 3.0
# Percentage of rising: 31.47%
# Percentage of falling: 35.77%
# Percentage of stable: 32.76%
# 6.0
# Percentage of rising: 31.09%
# Percentage of falling: 34.01%
# Percentage of stable: 34.90%
# 5.5
# Percentage of rising: 31.48%
# Percentage of falling: 34.36%
# Percentage of stable: 34.16%
# 5.5
# Percentage of rising: 30.92%
# Percentage of falling: 34.34%
# Percentage of stable: 34.74%
# 5.5
# Percentage of rising: 32.03%
# Percentage of falling: 34.22%
# Percentage of stable: 33.75%
# 5.5
# Percentage of rising: 31.75%
# Percentage of falling: 35.27%
# Percentage of stable: 32.98%
# 7.0
# Percentage of rising: 32.03%
# Percentage of falling: 33.95%
# Percentage of stable: 34.02%
# 6.0
# Percentage of rising: 32.21%
# Percentage of falling: 34.63%
# Percentage of stable: 33.17%
# 5.0
# Percentage of rising: 31.62%
# Percentage of falling: 34.11%
# Percentage of stable: 34.27%
# 4.0
# Percentage of rising: 30.37%
# Percentage of falling: 34.55%
# Percentage of stable: 35.08%
# 6.0
# Percentage of rising: 31.81%
# Percentage of falling: 34.89%
# Percentage of stable: 33.30%
# 5.5
# Percentage of rising: 31.69%
# Percentage of falling: 35.43%
# Percentage of stable: 32.88%
# 7.0
# Percentage of rising: 31.43%
# Percentage of falling: 35.38%
# Percentage of stable: 33.19%
# 6.0
# Percentage of rising: 31.88%
# Percentage of falling: 34.79%
# Percentage of stable: 33.33%
# 7.0
# Percentage of rising: 32.36%
# Percentage of falling: 33.85%
# Percentage of stable: 33.79%
# 5.5
# Percentage of rising: 31.40%
# Percentage of falling: 34.55%
# Percentage of stable: 34.05%
# 5.5
# Percentage of rising: 31.03%
# Percentage of falling: 34.70%
# Percentage of stable: 34.27%
# 6.0
# Percentage of rising: 32.32%
# Percentage of falling: 34.11%
# Percentage of stable: 33.58%
# 5.5
# Percentage of rising: 32.02%
# Percentage of falling: 35.43%
# Percentage of stable: 32.55%
# 2.5
# Percentage of rising: 31.24%
# Percentage of falling: 36.04%
# Percentage of stable: 32.73%
# 5.5
# Percentage of rising: 31.40%
# Percentage of falling: 34.35%
# Percentage of stable: 34.25%
# 5.5
# Percentage of rising: 32.26%
# Percentage of falling: 34.98%
# Percentage of stable: 32.76%
# 5.5
# Percentage of rising: 32.47%
# Percentage of falling: 35.02%
# Percentage of stable: 32.50%
# 6.5
# Percentage of rising: 31.65%
# Percentage of falling: 34.97%
# Percentage of stable: 33.38%
# 7.5
# Percentage of rising: 32.18%
# Percentage of falling: 33.81%
# Percentage of stable: 34.01%
# 6.5
# Percentage of rising: 31.85%
# Percentage of falling: 34.70%
# Percentage of stable: 33.44%
# 7.0
# Percentage of rising: 32.17%
# Percentage of falling: 35.19%
# Percentage of stable: 32.64%
# 7.5
# Percentage of rising: 31.53%
# Percentage of falling: 34.22%
# Percentage of stable: 34.25%
# 8.0
# Percentage of rising: 32.31%
# Percentage of falling: 34.23%
# Percentage of stable: 33.47%
# 8.0
# Percentage of rising: 32.58%
# Percentage of falling: 34.17%
# Percentage of stable: 33.25%
# 8.0
# Percentage of rising: 31.48%
# Percentage of falling: 35.16%
# Percentage of stable: 33.37%
# 8.0
# Percentage of rising: 31.77%
# Percentage of falling: 35.14%
# Percentage of stable: 33.09%
# 9.0
# Percentage of rising: 32.36%
# Percentage of falling: 34.78%
# Percentage of stable: 32.86%
# 9.0
# Percentage of rising: 32.03%
# Percentage of falling: 34.12%
# Percentage of stable: 33.85%
# 8.5
# Percentage of rising: 31.41%
# Percentage of falling: 34.23%
# Percentage of stable: 34.36%
# 8.5
# Percentage of rising: 31.77%
# Percentage of falling: 34.65%
# Percentage of stable: 33.59%
# 8.0
# Percentage of rising: 31.99%
# Percentage of falling: 34.67%
# Percentage of stable: 33.34%
# 8.0
# Percentage of rising: 31.93%
# Percentage of falling: 34.78%
# Percentage of stable: 33.29%
# 8.0
# Percentage of rising: 32.82%
# Percentage of falling: 34.55%
# Percentage of stable: 32.63%
# 8.5
# Percentage of rising: 31.91%
# Percentage of falling: 34.19%
# Percentage of stable: 33.90%
# 9.0
# Percentage of rising: 32.21%
# Percentage of falling: 34.06%
# Percentage of stable: 33.73%
# 8.0
# Percentage of rising: 31.92%
# Percentage of falling: 35.46%
# Percentage of stable: 32.62%
# 8.5
# Percentage of rising: 31.85%
# Percentage of falling: 34.41%
# Percentage of stable: 33.74%
# 8.5
# Percentage of rising: 32.20%
# Percentage of falling: 34.85%
# Percentage of stable: 32.96%
# 9.5
# Percentage of rising: 32.25%
# Percentage of falling: 33.44%
# Percentage of stable: 34.31%
# 9.0
# Percentage of rising: 31.76%
# Percentage of falling: 33.92%
# Percentage of stable: 34.32%
# 8.5
# Percentage of rising: 31.93%
# Percentage of falling: 34.45%
# Percentage of stable: 33.62%
# 9.5
# Percentage of rising: 32.27%
# Percentage of falling: 34.00%
# Percentage of stable: 33.73%
# 9.0
# Percentage of rising: 32.14%
# Percentage of falling: 34.43%
# Percentage of stable: 33.43%
# 8.5
# Percentage of rising: 32.25%
# Percentage of falling: 33.94%
# Percentage of stable: 33.81%
# 8.5
# Percentage of rising: 31.49%
# Percentage of falling: 34.70%
# Percentage of stable: 33.81%
# 9.0
# Percentage of rising: 32.66%
# Percentage of falling: 34.61%
# Percentage of stable: 32.73%
# 8.5
# Percentage of rising: 32.26%
# Percentage of falling: 35.11%
# Percentage of stable: 32.63%
# 9.0
# Percentage of rising: 33.00%
# Percentage of falling: 34.46%
# Percentage of stable: 32.54%
# 9.5
# Percentage of rising: 32.16%
# Percentage of falling: 34.38%
# Percentage of stable: 33.45%
# 9.5
# Percentage of rising: 32.34%
# Percentage of falling: 33.70%
# Percentage of stable: 33.96%
# 9.5
# Percentage of rising: 33.59%
# Percentage of falling: 35.41%
# Percentage of stable: 31.00%
# 9.5
# Percentage of rising: 32.42%
# Percentage of falling: 34.54%
# Percentage of stable: 33.05%
# 9.5
# Percentage of rising: 33.38%
# Percentage of falling: 35.17%
# Percentage of stable: 31.46%
# 9.5
# Percentage of rising: 32.59%
# Percentage of falling: 34.58%
# Percentage of stable: 32.83%
# 9.5
# Percentage of rising: 33.63%
# Percentage of falling: 35.99%
# Percentage of stable: 30.38%
# 9.5
# Percentage of rising: 32.14%
# Percentage of falling: 34.86%
# Percentage of stable: 33.00%
# 9.5
# Percentage of rising: 32.07%
# Percentage of falling: 34.99%
# Percentage of stable: 32.94%
# 9.5
# Percentage of rising: 32.74%
# Percentage of falling: 35.95%
# Percentage of stable: 31.31%
# 9.5
# Percentage of rising: 32.39%
# Percentage of falling: 35.51%
# Percentage of stable: 32.10%
# 9.5
# Percentage of rising: 32.39%
# Percentage of falling: 35.21%
# Percentage of stable: 32.39%
# 9.5
# Percentage of rising: 33.65%
# Percentage of falling: 36.17%
# Percentage of stable: 30.17%
# 9.5
# Percentage of rising: 33.29%
# Percentage of falling: 36.90%
# Percentage of stable: 29.81%
# 9.5
# Percentage of rising: 33.59%
# Percentage of falling: 35.94%
# Percentage of stable: 30.47%
# 9.5
# Percentage of rising: 33.31%
# Percentage of falling: 36.69%
# Percentage of stable: 30.00%
# 9.5
# Percentage of rising: 33.89%
# Percentage of falling: 36.17%
# Percentage of stable: 29.94%
# 9.5
# Percentage of rising: 32.63%
# Percentage of falling: 35.21%
# Percentage of stable: 32.16%
# 9.5
# Percentage of rising: 33.44%
# Percentage of falling: 36.59%
# Percentage of stable: 29.97%
# 9.5
# Percentage of rising: 33.08%
# Percentage of falling: 36.19%
# Percentage of stable: 30.73%
# 9.5
# Percentage of rising: 33.12%
# Percentage of falling: 35.21%
# Percentage of stable: 31.67%
# 9.5
# Percentage of rising: 33.97%
# Percentage of falling: 37.66%
# Percentage of stable: 28.37%
# 9.5
# Percentage of rising: 34.42%
# Percentage of falling: 37.46%
# Percentage of stable: 28.12%
# 9.5
# Percentage of rising: 33.00%
# Percentage of falling: 36.48%
# Percentage of stable: 30.52%
# 9.5
# Percentage of rising: 33.81%
# Percentage of falling: 36.56%
# Percentage of stable: 29.63%
# 9.5
# Percentage of rising: 34.34%
# Percentage of falling: 36.39%
# Percentage of stable: 29.27%
# 9.5
# Percentage of rising: 33.74%
# Percentage of falling: 36.00%
# Percentage of stable: 30.26%
# 9.5
# Percentage of rising: 33.54%
# Percentage of falling: 37.49%
# Percentage of stable: 28.97%
# 9.5
# Percentage of rising: 33.68%
# Percentage of falling: 36.66%
# Percentage of stable: 29.67%
# 9.5
# Percentage of rising: 33.72%
# Percentage of falling: 37.40%
# Percentage of stable: 28.87%
# 9.5
# Percentage of rising: 33.05%
# Percentage of falling: 36.33%
# Percentage of stable: 30.63%
# 9.5
# Percentage of rising: 34.17%
# Percentage of falling: 37.48%
# Percentage of stable: 28.34%
# 9.5
# Percentage of rising: 34.20%
# Percentage of falling: 36.68%
# Percentage of stable: 29.12%
# 9.5
# Percentage of rising: 34.43%
# Percentage of falling: 37.84%
# Percentage of stable: 27.73%
# 9.5
# Percentage of rising: 33.96%
# Percentage of falling: 36.05%
# Percentage of stable: 29.99%
# 9.5
# Percentage of rising: 33.54%
# Percentage of falling: 36.13%
# Percentage of stable: 30.33%
# 9.5
# Percentage of rising: 33.52%
# Percentage of falling: 37.07%
# Percentage of stable: 29.41%
# 9.5
# Percentage of rising: 32.97%
# Percentage of falling: 37.81%
# Percentage of stable: 29.22%
# 9.5
# Percentage of rising: 33.22%
# Percentage of falling: 36.11%
# Percentage of stable: 30.67%
# 9.5
# Percentage of rising: 34.34%
# Percentage of falling: 37.29%
# Percentage of stable: 28.37%

# %% [markdown]
# # -----( •̀ ω •́ )y--- I am a  dividing line -----( •̀ ω •́ )y-----
